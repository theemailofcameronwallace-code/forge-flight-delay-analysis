# %%
# !pwd
# !ls
# Out:
# /content
# sample_data

# %%
# !find / -name "flights.csv" 2>/dev/null
# Out:
# /flights.csv

# %%
import pandas as pd

flights = pd.read_csv("/flights.csv", nrows=5)

flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...           408
# 1            LAX                 PBI                   10  ...           741
# 2            SFO                 CLT                   20  ...           811
# 3            LAX                 MIA                   20  ...           756
# 4            SEA                 ANC                   25  ...           259
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %% [markdown]
# **Dataset Inspection and Cleaning**

# %%
print(flights.shape)
# Out:
# (5819079, 31)

# %%
print(flights.isnull().sum())
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# ...

# %%
print(flights.duplicated().sum())
# Out:
# 0

# %%
print(flights.dtypes)
# Out:
# YEAR                     int64
# MONTH                    int64
# DAY                      int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# SCHEDULED_DEPARTURE      int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE                 int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL        int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED                 int64
# CANCELLED                int64
# CANCELLATION_REASON     object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# ...

# %% [markdown]
# **Cleaning Plan**
#
# Missing Values
#
# Several columns regarding delays had missing values. These are most likely flights without delays. Missing values will either be kept as NULL values or converted to 0, depending on what analyses are conducted.
#
# Duplicates
#
# No duplicate rows were found.
#
# Data Types
#
# Columns were inspected to confirm numerical and categorical fields, allowing us to use SQL and MongoDB.
#
# Standardization
#
# Airport and airline identifiers will be standardized across tables for ease of data analysis.
#
# Date and Time Handling
#
# Date and time variables may be combined or reformatted depending on the analysis.
